# %%
rowsPending = True
offset = 0
chunkSize = 25000
csvFile = 'data/LEDGERTRANS.csv.gz'
csvIndex = 'LEDGERTRANSID'
while rowsPending:
    print (str(offset)  + " < chunkSize <= " + str(offset + chunkSize))
    if (offset == 0):
        print ("offset = 0")
    else:        
        print ("offset <> 0")    
    offset += chunkSize
    #if (len(chunk) < chunkSize):
    if offset > 1000001:
        rowsPending = False            
    #del chunk
# Out:
# 0 < chunkSize <= 25000
# offset = 0
# 25000 < chunkSize <= 50000
# offset <> 0
# 50000 < chunkSize <= 75000
# offset <> 0
# 75000 < chunkSize <= 100000
# offset <> 0
# 100000 < chunkSize <= 125000
# offset <> 0
# 125000 < chunkSize <= 150000
# offset <> 0
# 150000 < chunkSize <= 175000
# offset <> 0
# 175000 < chunkSize <= 200000
# offset <> 0
# 200000 < chunkSize <= 225000
# offset <> 0
# 225000 < chunkSize <= 250000
# offset <> 0
# 250000 < chunkSize <= 275000
# offset <> 0
# 275000 < chunkSize <= 300000
# offset <> 0
# 300000 < chunkSize <= 325000
# offset <> 0
# 325000 < chunkSize <= 350000
# offset <> 0
# 350000 < chunkSize <= 375000
# offset <> 0
# 375000 < chunkSize <= 400000
# offset <> 0
# 400000 < chunkSize <= 425000
# offset <> 0
# 425000 < chunkSize <= 450000
# offset <> 0
# 450000 < chunkSize <= 475000
# offset <> 0
# 475000 < chunkSize <= 500000
# offset <> 0
# 500000 < chunkSize <= 525000
# offset <> 0
# 525000 < chunkSize <= 550000
# offset <> 0
# 550000 < chunkSize <= 575000
# offset <> 0
# 575000 < chunkSize <= 600000
# offset <> 0
# 600000 < chunkSize <= 625000
# offset <> 0
# 625000 < chunkSize <= 650000
# offset <> 0
# 650000 < chunkSize <= 675000
# offset <> 0
# 675000 < chunkSize <= 700000
# offset <> 0
# 700000 < chunkSize <= 725000
# offset <> 0
# 725000 < chunkSize <= 750000
# offset <> 0
# 750000 < chunkSize <= 775000
# offset <> 0
# 775000 < chunkSize <= 800000
# offset <> 0
# 800000 < chunkSize <= 825000
# offset <> 0
# 825000 < chunkSize <= 850000
# offset <> 0
# 850000 < chunkSize <= 875000
# offset <> 0
# 875000 < chunkSize <= 900000
# offset <> 0
# 900000 < chunkSize <= 925000
# offset <> 0
# 925000 < chunkSize <= 950000
# offset <> 0
# 950000 < chunkSize <= 975000
# offset <> 0
# 975000 < chunkSize <= 1000000
# offset <> 0
# 1000000 < chunkSize <= 1025000
# offset <> 0
